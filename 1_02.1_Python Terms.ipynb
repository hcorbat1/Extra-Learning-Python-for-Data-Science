# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_02.1_Python Terms.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Example of Object (1.2.1.1)

# %% [markdown]
# x = 5
# x is a variable, but 5 is an object which has a type->int, it has data-> the value 5, and it has methods-> 5.bit_length()
# lst = [1,2,3], lst is a list object. Type-> list, data-> the elements inside, method-> append, pop, etc.

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Define Variable (1.2.1.2)

# %% [markdown]
# x = 10 (x is a variable)
# name = 'HC' (name is a variable)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Function (1.2.1.3)

# %% [markdown]
# def add_numbers(a,b):
#     return a + b
# result = add_numbers(3,5)
# print(result)
#
# in programming, a function is a reusable block of code that performs a specific task
# it has a name(add_numbers), it takes inputs(a,b), performs actions (a + b), and returns an output(return)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Class (1.2.1.4)

# %% [markdown]
# In programming, a class is a blueprint for creating objects.
#
# Simple definition
#
# A class defines:
#
# Attributes (data the object holds)
#
# Methods (actions the object can perform)

# %%
# Python example
class Dog:
    def __init__(self, name, age):
        self.name = name    # attribute
        self.age = age      # attribute

    def bark(self):         # method
        print("Woof!")

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Call Method (1.2.1.5)

# %%
text = 'hello'
text_upper = text.upper()   #calling the .upper() method

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Example of Attribute (1.2.1.6)

# %% [markdown]
# an attribute = a property, characteristic, or piece of data that belongs to something
# a car has attributes like:
# color = 'blue'
# mileage = 50,000
# model = ' Toyota Camry'

# %% [markdown]
# ---
